# %%
pip install pandas
# Out:
# ...
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('saumil.csv')
df
# Out:
#     Year               Player           Selling club           Buying club  \
# 0   1893        Willie Groves   West Bromwich Albion           Aston Villa
# 1   1903            Ben Green               Barnsley           Small Heath
# 2   1904       Alf Common (1)       Sheffield United            Sunderland
# 3   1904        Andy McCombie             Sunderland      Newcastle United
# 4   1905       Alf Common (2)             Sunderland         Middlesbrough
# 5   1913          Daniel Shea        West Ham United      Blackburn Rovers
# 6   1913         Tommy Barber       Bolton Wanderers           Aston Villa
# 7   1914         Percy Dawson    Heart of Midlothian      Blackburn Rovers
# 8   1920       David Jack (1)        Plymouth Argyle      Bolton Wanderers
# 9   1921         Tom Hamilton             Kilmarnock     Preston North End
# 10  1922        Syd Puddefoot        West Ham United               Falkirk
# ...

# %%
df.loc[1]
# Out:
# Year                    1903
# Player             Ben Green
# Selling club        Barnsley
# Buying club      Small Heath
# Fee (£)              500[77]
# Name: 1, dtype: object

# %%
df.head(4)
# Out:
#    Year           Player           Selling club        Buying club  Fee (£)
# 0  1893    Willie Groves   West Bromwich Albion        Aston Villa   100[2]
# 1  1903        Ben Green               Barnsley        Small Heath  500[77]
# 2  1904   Alf Common (1)       Sheffield United         Sunderland  520[78]
# 3  1904    Andy McCombie             Sunderland   Newcastle United  700[79]

# %%
len(df)
# Out:
# 49

# %%
df.head()
# Out:
#    Year           Player           Selling club        Buying club    Fee (£)
# 0  1893    Willie Groves   West Bromwich Albion        Aston Villa     100[2]
# 1  1903        Ben Green               Barnsley        Small Heath    500[77]
# 2  1904   Alf Common (1)       Sheffield United         Sunderland    520[78]
# 3  1904    Andy McCombie             Sunderland   Newcastle United    700[79]
# 4  1905   Alf Common (2)             Sunderland      Middlesbrough  1,000[80]

# %%
df.tail(2)
# Out:
#     Year       Player Selling club           Buying club            Fee (£)
# 47  2016   Paul Pogba     Juventus     Manchester United     89,000,000[98]
# 48  2017       Neymar    Barcelona   Paris Saint-Germain  198,000,000[3][4]

# %%
df.Player
# Out:
# 0           Willie Groves
# 1               Ben Green
# 2          Alf Common (1)
# 3           Andy McCombie
# 4          Alf Common (2)
# 5             Daniel Shea
# 6            Tommy Barber
# 7            Percy Dawson
# 8          David Jack (1)
# 9            Tom Hamilton
# 10          Syd Puddefoot
# 11       Warney Cresswell
# 12              Bob Kelly
# 13         David Jack (2)
# 14       Bernabé Ferreyra
# 15          Johnny Morris
# 16          Eddie Quigley
# 17            Trevor Ford
# 18          Jackie Sewell
# 19           Hans Jeppson
# 20        Juan Schiaffino
# 21            Omar Sivori
# 22            Luis Suárez
# 23         Angelo Sormani
# 24         Harald Nielsen
# 25        Pietro Anastasi
# 26           Johan Cruyff
# 27       Giuseppe Savoldi
# 28            Paolo Rossi
# 29     Diego Maradona (1)
# 30     Diego Maradona (2)
# 31            Ruud Gullit
# 32         Roberto Baggio
# 33      Jean-Pierre Papin
# 34        Gianluca Vialli
# ...

# %%
df.Player.head()
# Out:
# 0      Willie Groves
# 1          Ben Green
# 2     Alf Common (1)
# 3      Andy McCombie
# 4     Alf Common (2)
# Name: Player, dtype: object

# %%
df.query('Year > 1983').head(2)
# Out:
#     Year               Player    Selling club Buying club        Fee (£)
# 30  1984   Diego Maradona (2)       Barcelona      Napoli  5,000,000[89]
# 31  1987          Ruud Gullit   PSV Eindhoven       Milan  6,000,000[89]

# %%
df.columns
# Out:
# Index(['Year', 'Player', 'Selling club', 'Buying club', 'Fee (£)'], dtype='object')

# %%
df.columns[2]
# Out:
# 'Selling club'

# %%
df.loc[[0,3,5]]
# Out:
#    Year          Player           Selling club        Buying club    Fee (£)
# 0  1893   Willie Groves   West Bromwich Albion        Aston Villa     100[2]
# 3  1904   Andy McCombie             Sunderland   Newcastle United    700[79]
# 5  1913     Daniel Shea        West Ham United   Blackburn Rovers  2,000[81]
